# %% [markdown]
# MY JUPITER NOTEBOOK ON IBM WATSON STUDIO

# %% [markdown]
# AGBODIKE DYMPHNA
# ENVIRONMENTAL HEALTH OFFICER

# %% [markdown]
# data science languages are
# python
# SQL
# JAVA
# SCALA

# %% [markdown]
# Cell 5 will show you my calculations 50 divided by 25 gives you 2 and 25 multiplied by 2 gives you 50

# %% [markdown]
# Data science libraries
# scikit~learn
# TensorFlow
# PyTorch
# Theano

# %% [markdown]
# arithmatic example

# %%
(50/25)*2

# %%
min = seconds // 60

# %% [markdown]
# OBJECTIVES
# TO WRITE ON JUPYTER USING MARKDOWN OR PYTHON
# TO BE ABLE TO UPLOAD ON GITHUB

# %% [markdown]
# ARTHUR'S NAME : AGBODIKE DYMPHNA

# %% [markdown]
# #### Add your code below following the instructions given in the course
